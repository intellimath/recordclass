# %%
from recordclass import recordclass

# %%
ABC = recordclass('AA', "a b c",
                   defaults={"c":1}, mapping=True, use_dict=True)

EFG = recordclass('BB', "c d e",
                  defaults={"e":2}, mapping=True, use_dict=True)

# %%
ABC(1,2)
# Out:
# AA(a=1, b=2, c=1)

# %%
EFG(1,)
# Out:
# BB(c=1, d=None, e=2)
