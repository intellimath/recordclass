# %%
from recordclass import dataobject
import sys
print(sys.version)

class Point(dataobject):
  x: int
  y: int

point_kwargs = {'x': 1, 'y':2, 'z': 10}

p = Point(**point_kwargs)
# Out:
# 3.14.6 (main, Jun 10 2026, 18:54:31) [GCC 15.2.0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7   y: int
#       8
#       9 point_kwargs = {'x': 1, 'y':2, 'z': 10}
#      10
# ---> 11 p = Point(**point_kwargs)
#
# TypeError: Invalid kwarg: z not in __fields__
